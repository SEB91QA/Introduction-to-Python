# %%
def square(number):
    """Calculate the square number"""
    return number**2

# %%
square(7)
# Out:
# 49

# %%
square(2.5)
# Out:
# 6.25

# %%
print('The square of 7 is:', square(7))
# Out:
# The square of 7 is: 49

# %%
square?
# Out:
# Signature: square(number)
# Docstring: Calculate the square number
# File:      /var/folders/78/hgt6ztdn5bvbxpk7fmt5jlfc0000gn/T/ipykernel_1722/4275434872.py
# Type:      function

# %%
square??
# Out:
# Signature: square(number)
# Source:
# def square(number):
#     """Calculate the square number"""
#     return number**2
# File:      /var/folders/78/hgt6ztdn5bvbxpk7fmt5jlfc0000gn/T/ipykernel_1722/4275434872.py
# Type:      function

# %%
def square_root(x):
    '''Calculate the square root number'''
    return x**0.5

# %%
square_root(6.25)
# Out:
# 2.5

# %%
def maximum(value1, value2, value3):
    '''Returns the highest value'''
    max_value = value1
    if value2 > max_value:
        max_value = value2
    if value3 > max_value:
        max_value = value3
    return max_value


maximum(12, 27, 36)
# Out:
# 36

# %%
maximum(12.3, 45.6, 9.7)
# Out:
# 45.6

# %%
maximum('yellow', 'red', 'orange')
# Out:
# 'yellow'

# %%
maximum(13.5, -3, 7)
# Out:
# 13.5

# %%
max('yellow', 'red', 'orange', 'blue', 'green')
# Out:
# 'yellow'

# %%
min(15, 9, 27, 14)
# Out:
# 9

# %%
import random  # pseudorandom numbers

for roll in range(10):
    print(random.randrange(1, 7), end=' ')
# Out:
# 1 6 1 6 2 3 6 6 5 1

# %%
frequency1 = 0
frequency2 = 0
frequency3 = 0
frequency4 = 0
frequency5 = 0
frequency6 = 0

for roll in range(6_000_000):
    face = random.randrange(1, 7)

    if face == 1:
        frequency1 += 1
    if face == 2:
        frequency2 += 1
    if face == 3:
        frequency3 += 1
    if face == 4:
        frequency4 += 1
    if face == 5:
        frequency5 += 1
    if face == 6:
        frequency6 += 1

print(f'Face{"Frequency":>13}')
print(f'{1:>4}{frequency1:>13}')
print(f'{2:>4}{frequency2:>13}')
print(f'{3:>4}{frequency3:>13}')
print(f'{4:>4}{frequency4:>13}')
print(f'{5:>4}{frequency5:>13}')
print(f'{6:>4}{frequency6:>13}')
# Out:
# Face    Frequency
#    1      1000527
#    2       999180
#    3      1000086
#    4       999507
#    5      1000385
#    6      1000315

# %%
random.seed(32)

for roll in range(10):
    print(random.randrange(1, 7), end=' ')
# Out:
# 1 2 2 3 6 2 4 1 6 1

# %%
for roll in range(10):
    print(random.randrange(1, 7), end=' ')
# Out:
# 1 3 5 3 1 5 6 4 3 5

# %%
random.seed(32)

for roll in range(10):
    print(random.randrange(1, 7), end=' ')
# Out:
# 1 2 2 3 6 2 4 1 6 1

# %%
import random

for i in range(20):
    print('H' if random.randrange(2) == 0 else 'T', end=' ')  # Interesting syntax
# Out:
# H T T T H T H H T H H H H T H T H T H H

# %%
'''Case Study: A Game of Chance. Craps'''
import random


def roll_dice():
    '''Roll two dice and return their face values as a tuple'''
    die1 = random.randrange(1, 7)
    die2 = random.randrange(1, 7)
    return (die1, die2)


def display_dice(dice):
    '''Display one roll of the two dice'''
    die1, die2 = dice
    print(f"Player rolled {die1} + {die2} = {sum(dice)}")


die_values = roll_dice()  # first roll
display_dice(die_values)
sum_of_dice = sum(die_values)

if sum_of_dice in (7, 11):
    game_status = 'WON'

elif sum_of_dice in (2, 3, 12):
    game_status = 'LOST'

else:
    game_status = 'CONTINUE'
    my_point = sum_of_dice
    print('Point is', my_point)

'''Continue rolling until player wins or loses'''
while game_status == 'CONTINUE':
    die_values = roll_dice()
    display_dice(die_values)
    sum_of_dice = sum(die_values)

    if sum_of_dice == my_point:
        game_status = 'WON'
    elif sum_of_dice == 7:
        game_status = 'LOST'

if game_status == 'WON':
    print('Player wins')
else:
    print('Player loses')
# Out:
# Player rolled 4 + 3 = 7
# Player wins

# %%
student = ('Sue', [89, 94, 85])
student
# Out:
# ('Sue', [89, 94, 85])

# %%
name, grades = student
name
# Out:
# 'Sue'

# %%
grades
# Out:
# [89, 94, 85]

# %%
import math

math.sqrt(900)
# Out:
# 30.0

# %%
math.fabs(-10)
# Out:
# 10.0

# %%
math.fabs?
# Out:
# Signature: math.fabs(x, /)
# Docstring: Return the absolute value of the float x.
# Type:      builtin_function_or_method

# %%
#  Default Parameter Values
def rectangle_area(length=2, width=3):
    '''Return the rectables area'''
    return length*width


rectangle_area()
# Out:
# 6

# %%
rectangle_area(10)
# Out:
# 30

# %%
rectangle_area(10, 5)
# Out:
# 50

# %%
#  Keyword Arguments
#  You can use keyword arguments to pass arguments in any order.

def rectangle_area(length, width):
    '''Return a rectangle's area'''
    return length*width


rectangle_area(width=5, length=10)
# Out:
# 50

# %%
#  Arbitrary argument lists
def average(*args):
    return sum(args)/len(args)


average(5, 10)
# Out:
# 7.5

# %%
average(5, 10, 15)
# Out:
# 10.0

# %%
average(5, 10, 55, 20)
# Out:
# 22.5

# %%
grades = [88, 75, 96, 55, 83]

#  *operator, when applied to an iterable argument in a function, unpacks its elements.
average(*grades)
# Out:
# 79.4

# %%
def calculate_product(*args):
    p = 1
    for i in args:
        p *= i
    return p


calculate_product(5, 1)
# Out:
# 5

# %%
calculate_product(10, 20, 30)
# Out:
# 6000

# %%
calculate_product(*range(1, 6, 2))
# Out:
# 15

# %%
s = 'Hello'

s.lower()
# Out:
# 'hello'

# %%
s.upper()
# Out:
# 'HELLO'

# %%
s
# Out:
# 'Hello'

# %%
x = 7


def access_global():
    print('x printed from access_global:', x)


access_global()
# Out:
# x printed from access_global: 7

# %%
def try_to_modify_global():
    x = 3.5
    print('x printed from try_to_modify_global:', x)


try_to_modify_global()
# Out:
# x printed from try_to_modify_global: 3.5

# %%
x
# Out:
# 7

# %%
def modify_global():
    global x
    x = 'hello'
    print('x printed from modify_global:', x)
    

modify_global()
# Out:
# x printed from modify_global: hello

# %%
from math import ceil, floor

ceil(10.3)
# Out:
# 11

# %%
floor(10.7)
# Out:
# 10

# %%
import statistics as stats

grades = [85, 93, 45, 87, 93]

stats.mean(grades)
# Out:
# 80.6

# %%
import decimal as dec

v = dec.Decimal(2.5)
v ** 2
# Out:
# Decimal('6.25')

# %%
## Passing Arguments to Functions: A deeper look

x = 7
id(x)
# Out:
# 4458575272

# %%
def cube(number):
    print('id(number):', id(number))
    return number ** 3


cube(x)
# Out:
# id(number): 4458575272
# 343

# %%
def cube(number):
    print('number is x:', number is x)
    return number ** 3


cube(x)
# Out:
# number is x: True
# 343

# %%
def cube(number):
    print('id(number) before modifying number:', id(number))
    number **= 3
    print('id(number) after modifying number:', id(number))
    return number


cube(x)
# Out:
# id(number) before modifying number: 4458575272
# id(number) after modifying number: 5126559536
# 343

# %%
print(f'x={x}; id(x)={id(x)}')
# Out:
# x=7; id(x)=4458575272

# %%
width = 7.5

cube(width)
# Out:
# id(number) before modifying number: 5126555184
# id(number) after modifying number: 5126561776
# 421.875
